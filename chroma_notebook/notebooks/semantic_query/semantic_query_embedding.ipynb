# %% [markdown]
# # Busca Semântica com Embeddings

# %% [markdown]
# ## Gerando Embeddings

# %% [markdown]
# * ### Importando as bibliotecas

# %%
from decouple import config
from google import genai
from google.genai import types

# %% [markdown]
# * ### Carregando as variáveis de ambiente

# %%
PROJECT_ID = config("GOOGLE_CLOUD_PROJECT")
LOCATION = config("GOOGLE_CLOUD_LOCATION")
MODEL_ID = config("MODEL_NAME")

# %% [markdown]
# * ### Instanciando o Client

# %%
client = genai.Client(
    vertexai=True,
    project=PROJECT_ID,
    location=LOCATION
)

# %% [markdown]
# * ### Definindo os textos que serão vetorizados

# %%
texts = [
    "Como usar embeddings no Python",
    "Vertex AI generative AI",
]

# %% [markdown]
# * ### Criandao os embeddings

# %%
result = client.models.embed_content(
    model=MODEL_ID,
    contents=texts,
    config=types.EmbedContentConfig(
        task_type="RETRIEVAL_DOCUMENT"
    )
)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 result = client.models.embed_content(
#       2     model=MODEL_ID,
#       3     contents=texts,
#       4     config=types.EmbedContentConfig(
#       5         task_type="RETRIEVAL_DOCUMENT"
#       6     )
#       7 )
#
# File /opt/conda/lib/python3.11/site-packages/google/genai/models.py:6200, in Models.embed_content(self, model, contents, config)
#    6195   if len(normalized_contents) > 1:
#    6196     raise ValueError(
#    6197         'The embedContent API for this model only supports one content at a'
#    6198         ' time.'
#    6199     )
# -> 6200   return self._embed_content(
#    6201       model=model,
#    6202       contents=None,
#    6203       content=normalized_contents[0],
#    6204       embedding_api_type=types.EmbeddingApiType.EMBED_CONTENT,
#    6205       config=config,
#    6206   )
#    6207 else:
#    6208   return self._embed_content(
#    6209       model=model,
#    6210       content=None,
#    (...)
#    6213       config=config,
#    6214   )
#
# File /opt/conda/lib/python3.11/site-packages/google/genai/models.py:4996, in Models._embed_content(self, model, contents, content, embedding_api_type, config)
#    4993 request_dict = _common.convert_to_dict(request_dict)
#    4994 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4996 response = self._api_client.request(
#    4997     'post', path, request_dict, http_options
#    4998 )
#    5000 response_dict = {} if not response.body else json.loads(response.body)
#    5002 if self._api_client.vertexai:
#
# File /opt/conda/lib/python3.11/site-packages/google/genai/_api_client.py:1605, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1595 def request(
#    1596     self,
#    1597     http_method: str,
#    (...)
#    1600     http_options: Optional[HttpOptionsOrDict] = None,
#    1601 ) -> SdkHttpResponse:
#    1602   http_request = self._build_request(
#    1603       http_method, path, request_dict, http_options
#    1604   )
# -> 1605   response = self._request(http_request, http_options, stream=False)
#    1606   response_body = (
#    1607       response.response_stream[0] if response.response_stream else ''
#    1608   )
#    1609   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File /opt/conda/lib/python3.11/site-packages/google/genai/_api_client.py:1398, in BaseApiClient._request(self, http_request, http_options, stream)
#    1395     retry = tenacity.Retrying(**retry_kwargs)
#    1396     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1398 return self._retry(self._request_once, http_request, stream)
#
# File /opt/conda/lib/python3.11/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File /opt/conda/lib/python3.11/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File /opt/conda/lib/python3.11/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File /opt/conda/lib/python3.11/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File /opt/conda/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/conda/lib/python3.11/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /opt/conda/lib/python3.11/site-packages/google/genai/_api_client.py:1327, in BaseApiClient._request_once(self, http_request, stream)
#    1325 # If using proj/location, fetch ADC
#    1326 if self.vertexai and (self.project or self.location):
# -> 1327   http_request.headers['Authorization'] = f'Bearer {self._access_token()}'
#    1328   if self._credentials and self._credentials.quota_project_id:
#    1329     http_request.headers['x-goog-user-project'] = (
#    1330         self._credentials.quota_project_id
#    1331     )
#
# File /opt/conda/lib/python3.11/site-packages/google/genai/_api_client.py:1155, in BaseApiClient._access_token(self)
#    1153 with self._sync_auth_lock:
#    1154   if not self._credentials:
# -> 1155     self._credentials, project = load_auth(project=self.project)
#    1156     if not self.project:
#    1157       self.project = project
#
# File /opt/conda/lib/python3.11/site-packages/google/genai/_api_client.py:193, in load_auth(project)
#     191 def load_auth(*, project: Union[str, None]) -> Tuple[Credentials, str]:
#     192   """Loads google auth credentials and project id."""
# --> 193   credentials, loaded_project_id = google.auth.default(  # type: ignore[no-untyped-call]
#     194       scopes=['https://www.googleapis.com/auth/cloud-platform'],
#     195   )
#     197   if not project:
#     198     project = loaded_project_id
#
# File /opt/conda/lib/python3.11/site-packages/google/auth/_default.py:748, in default(scopes, request, quota_project_id, default_scopes)
#     740             _LOGGER.warning(
#     741                 "No project ID could be determined. Consider running "
#     742                 "`gcloud config set project` or setting the %s "
#     743                 "environment variable",
#     744                 environment_vars.PROJECT,
#     745             )
#     746         return credentials, effective_project_id
# --> 748 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
